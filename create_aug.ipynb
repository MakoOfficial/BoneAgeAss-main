# %%
import collections
import math
import os
import shutil
import pandas as pd
import torch
import torchvision
from torch import nn
from d2l import torch as d2l
import myKit

data_dir = os.path.join('..', 'data', 'test')

transform_train = torchvision.transforms.Compose([
    # 随机裁剪图像，所得图像为原始面积的0.08～1之间，高宽比在3/4和4/3之间。
    # 然后，缩放图像以创建224x224的新图像
    torchvision.transforms.RandomResizedCrop(224, scale=(0.08, 1.0),
                                             ratio=(3.0/4.0, 4.0/3.0)),
    torchvision.transforms.RandomHorizontalFlip(),
    # 随机更改亮度，对比度和饱和度
    torchvision.transforms.ColorJitter(brightness=0.4,
                                       contrast=0.4,
                                       saturation=0.4),
    # 添加随机噪声
    torchvision.transforms.ToTensor(),
    # 标准化图像的每个通道
    torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                     [0.229, 0.224, 0.225])])

def read_csv_labels(fname):
    """读取fname来给标签字典返回一个文件名"""
    with open(fname, 'r') as f:
        # 跳过文件头行(列名)
        lines = f.readlines()[1:]
    tokens = [l.rstrip().split(',') for l in lines]
    return dict(((name, label) for name, label in tokens))

labels = read_csv_labels(os.path.join(data_dir, 'labels.csv'))
print('# 训练样本 :', len(labels))
print('# 类别 :', len(set(labels.values())))
# Out:
# # 训练样本 : 12611
# # 类别 : 160

# %%
import numpy as np
import matplotlib.pyplot as  plt

# %%
def copyfile(filename, target_dir):
    """将文件复制到目标目录"""
    os.makedirs(target_dir, exist_ok=True)
    shutil.copy(filename, target_dir)

# %%
def reorg_train(data_dir, labels):
    # 验证集中每个类别的样本数
    for train_file in os.listdir(os.path.join(data_dir, 'train')):
        label = labels[train_file.split('.')[0]]
        fname = os.path.join(data_dir, 'train', train_file)
        copyfile(fname, os.path.join(data_dir, 'train_valid_test',
                                     'train_valid', label))

# %%
# reorg_train(data_dir, labels)

# %%
def reorg_small_train(data_dir, labels, size):
    # 验证集中每个类别的样本数
    count = 0
    for train_file in os.listdir(os.path.join(data_dir, 'train')):
        label = labels[train_file.split('.')[0]]
        fname = os.path.join(data_dir, 'train', train_file)
        copyfile(fname, os.path.join(data_dir, 'train_valid_test',
                                     'small', label))
        count += 1
        if count > size:
            break

# %%
# reorg_small_train(data_dir, labels, 2000)

# %%
def sample_normalize(image, **kwargs):
    """标准化每个通道"""
    # image = image // 255
    channel = image.shape[2]
    mean, std = image.reshape((-1, channel)).mean(axis=0), image.reshape((-1, channel)).std(axis=0)
    return (image - mean) / (std + 1e-3)

# %%
transform_train = torchvision.transforms.Compose([
    # 随机裁剪图像，所得图像为原始面积的0.08～1之间，高宽比在3/4和4/3之间。
    # 然后，缩放图像以创建224x224的新图像
    torchvision.transforms.RandomResizedCrop(512, scale=(0.08, 1.0),
                                             ratio=(3.0/4.0, 4.0/3.0)),
    torchvision.transforms.RandomHorizontalFlip(),
    # 随机更改亮度，对比度和饱和度
    torchvision.transforms.ColorJitter(brightness=0.4,
                                       contrast=0.4,
                                       saturation=0.4),
    # 添加随机噪声
    torchvision.transforms.ToTensor(),
    # 标准化图像的每个通道
    torchvision.transforms.Normalize([0.485, 0.456, 0.406],
                                     [0.229, 0.224, 0.225])])

# %%
batch_size = 10

# %%
train_ds, small_ds = [torchvision.datasets.ImageFolder(
    os.path.join(data_dir, 'train_valid_test', folder),
    transform=transform_train) for folder in ['train', 'small']]

# %%
train_iter, small_iter = [torch.utils.data.DataLoader(
    dataset, batch_size, shuffle=True, drop_last=True)
    for dataset in (train_ds, small_ds)]

# %%
def get_net(devices):
    finetune_net = nn.Sequential()
    finetune_net.features = torchvision.models.resnet34(pretrained=True)
    # 定义一个新的输出网络，共有120个输出类别
    finetune_net.output_new = nn.Sequential(nn.Linear(1000, 256),
                                            nn.ReLU(),
                                            nn.Linear(256, 230))
    # 将模型参数分配给用于计算的CPU或GPU
    finetune_net = finetune_net.to(device=devices[0])
    # 冻结参数
    for param in finetune_net.features.parameters():
        param.requires_grad = False
    return finetune_net

# %%
# 定义损失函数
loss = nn.CrossEntropyLoss(reduction='none')

# %%
devices, num_epochs, lr, wd = d2l.try_all_gpus(), 50, 1e-4, 1e-4
lr_period, lr_decay = 25, 0.9

# %%
# net = myKit.get_net(isEnsemble=False)

# %%
len(small_iter)
# Out:
# 200

# %%
def train(net, train_iter, num_epochs, lr, wd, devices, lr_period, lr_decay):
    # 只训练小型自定义输出网络
    net = nn.DataParallel(net, device_ids=devices).to(devices[0])
    trainer = torch.optim.SGD((param for param in net.parameters()
                               if param.requires_grad), lr=lr, momentum=0.9, weight_decay=wd)
    scheduler = torch.optim.lr_scheduler.StepLR(trainer, lr_period, lr_decay)
    num_batches, timer = len(train_iter), d2l.Timer()
    legend = ['train loss']
    animator = d2l.Animator(xlabel='epoch', xlim=[1, num_epochs],
                            legend=legend)
    for epoch in range(num_epochs):
        metric = d2l.Accumulator(2)
        for i, (features, labels) in enumerate(train_iter):
            timer.start()
            features, labels = features.to(devices[0]), labels.to(devices[0])
            trainer.zero_grad()
            output = net(features)
            l = loss(output, labels).sum()
            l.backward()
            trainer.step()
            metric.add(l, labels.shape[0])
            timer.stop()
            if (i + 1) % (num_batches // 10) == 0 or i == num_batches - 1:
                print(f'i:{i}')
                animator.add(epoch + (i + 1) / num_batches,
                             (metric[0] / metric[1], None))
        print(f'epoch:{epoch}')
        measures = f'train loss {metric[0] / metric[1]:.3f}'
        scheduler.step()
    print(measures + f'\n{metric[1] * num_epochs / timer.sum():.1f}'
          f' example/sec on {str(devices)}')
    torch.save(net, './new_module.pth')

# %%
# train(net, small_iter, num_epochs, lr, wd, devices, lr_period,
#       lr_decay)

# %%
def accuracy(y_hat, y):
    if len(y_hat.shape) > 1 and y_hat.shape[1] > 1:
        y_hat = d2l.argmax(y_hat, axis=1)
    cmp = d2l.astype(y_hat, y.dtype) == y
    return float(d2l.reduce_sum(d2l.astype(cmp, y.dtype)))

# %%
def evaluate_loss(data_iter, net, devices):
    net.eval()
    pred_list = []  #
    grand_age = []  #
    for i, (features, labels) in enumerate(data_iter):
        features, labels = features.to(devices[0]), labels.to(devices[0])
        outputs = net(features)
        outputs = outputs.cpu()
        pred_list.extend(outputs)
        grand_age.extend(labels)
    return accuracy(pred_list, grand_age)

# %%
eval_net = torch.load('./new_module.pth')

# %%
print(eval_net)
# Out:
# DataParallel(
#   (module): MMANet_BeforeGA(
#     (backbone1): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
evaluate_loss(small_iter, eval_net, devices)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# f:\GitCode\BoneAgeAss-main\BoneAgeAss-main\create_aug.ipynb Cell 24 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/f%3A/GitCode/BoneAgeAss-main/BoneAgeAss-main/create_aug.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> evaluate_loss(small_iter, eval_net, devices)
#
# f:\GitCode\BoneAgeAss-main\BoneAgeAss-main\create_aug.ipynb Cell 24 in evaluate_loss(data_iter, net, devices)
#       <a href='vscode-notebook-cell:/f%3A/GitCode/BoneAgeAss-main/BoneAgeAss-main/create_aug.ipynb#X31sZmlsZQ%3D%3D?line=4'>5</a> for i, (features, labels) in enumerate(data_iter):
#       <a href='vscode-notebook-cell:/f%3A/GitCode/BoneAgeAss-main/BoneAgeAss-main/create_aug.ipynb#X31sZmlsZQ%3D%3D?line=5'>6</a>     features, labels = features.to(devices[0]), labels.to(devices[0])
# ...
